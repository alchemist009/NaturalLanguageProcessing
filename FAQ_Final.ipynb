# %%
# !pip install --upgrade pip

# %%
# !pip install pattern

# %%
# !pip install https://github.com/clips/pattern/archive/development.zip

# %%
# !pip install pixiedust

# %%
# import pixiedust

from pattern.en import parse, pprint, parsetree, wordnet

from pattern.vector import Document, Model, TFIDF
from pattern.vector import stem, PORTER, LEMMA
from pattern.vector import SVM, RADIAL, gridsearch, kfoldcv, count
from pattern.vector import distance, COSINE, tfidf

# For Latent Semantic Analysis (LSA)
import numpy as np
from numpy.linalg import svd
from numpy import dot, diag


import gensim
from gensim.models import doc2vec, KeyedVectors
from gensim.models.doc2vec import Doc2Vec, LabeledSentence

import pyemd

import re
import math
import operator
from collections import Counter
# Out:
# c:\python37\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def readAndCreateCorpus():
    with open("FAQs.txt") as f:
        for line in f:
            if(re.match(r"^[0-9]{1,}.", line)):
                question = re.sub(r"^[0-9]{1,}. (.*)", "\\1", line)
                qlines.append(question)
                pass
            elif(re.match(r"^[A].", line)):
                answer = re.sub(r"^[A]. (.*)", "\\1", line)
                alines.append(answer)
                pass
            pass
        pass
    
    for i in range(len(qlines)):
        qa = qlines[i] + alines[i]
        # corpus.append(qa)
        # documents.append({"Q" : qlines[i], "A" : alines[i]})
        documents.append(qa)
        pass
    pass

# %%
def createContainer():
    for i in range(len(documents)):
        qaDocs.append(Document(documents[i], stemmer = LEMMA, name = "DOC {}".format(i)))
        
        # pos = parse(documents[i], lemmata = True)
        parse_tree = parsetree(documents[i], lemmata = True)
        
        DOC_WORDS = list()
        
        word = None
        pos = None
        lemma = None
        stemmed = None
        wordnetted = dict()
        
        for sentence in parse_tree:
            
            heads = list()
            for chunk in sentence.chunks:        
                heads.append(chunk.head)
                pass
            
            container.update({"DOC {}".format(i) : {"heads" : heads}})
            
            for w in sentence:
                word = w.string
                pos = w.pos
                lemma = w.lemma
                stemmed = stem(word, stemmer = LEMMA)

                hypernyms = list()
                hyponyms = list()
                holonyms = list()
                meronyms = list()

                synsetList = wordnet.synsets(word)
                for synset in synsetList:
                    hypernyms.append(synset.hypernyms())
                    hyponyms.append(synset.hyponyms())
                    holonyms.append(synset.holonyms())
                    meronyms.append(synset.meronyms())
                    pass

                wordnetted = {"hypernyms" : hypernyms,
                 "hyponyms" : hyponyms,
                 "holonyms" : holonyms,
                 "meronyms" : meronyms}
                
                DOC_WORDS.append({word : {"pos" : pos, "stemmed" : stemmed, "lemma" : lemma, "wordneted" : wordnetted}})
                pass
            pass
        
        container.get("DOC {}".format(i)).update({"deptree" : parse_tree, "DOC_WORDS" : DOC_WORDS})
        pass
    pass

# %%
# Calculating the match score for the input query against each of the FAQs
def match_qa_pair(input_bag):
    match_score = dict()
    
    for word in re.findall(r"\w+", input_bag):
        for i in range(len(bagofwords)):
            if word in bagofwords[i].keys():
                match_score[i] = match_score.get(i, 0) + 1
                pass
            else:
                match_score[i] = 0
                pass
            pass
        pass
    
    # print(match_score)
    
    """
    maximum = max(match_score.items(), key=lambda k : k[1])
    # print(maximum[0])
    
    for key in match_score:
        if key == maximum[0]:
            print("The matching question is: " + qlines[key])
            print("The matching answer is: " + alines[key])
            pass
        pass
    """
    
    # print(sorted(match_score.items(), key=operator.itemgetter(1), reverse = True)[:10])
    
    for key in sorted(match_score.keys(), key = lambda x : str(match_score[x]), reverse = True)[:10]:
        print("The matching question is: " + qlines[key])
        print("The matching answer is: " + alines[key])
        print("\n\n")
        pass    
    pass

# %%
def createInputContainer(inputSentence):
    inputContainer = dict()
    # pos = parse(inputSentence, lemmata = True)
    parse_tree = parsetree(inputSentence, lemmata = True)
    
    DOC_WORDS = list()

    word = None
    pos = None
    lemma = None
    stemmed = None
    wordnetted = dict()

    for sentence in parse_tree:
        
        heads = list()
        for chunk in sentence.chunks:        
            heads.append(chunk.head)
            pass
        
        inputContainer.update({"Input" : {"heads" : heads}})
        
        for w in sentence:
            word = w.string
            pos = w.pos
            lemma = w.lemma
            stemmed = stem(word, stemmer = LEMMA)

            hypernyms = list()
            hyponyms = list()
            holonyms = list()
            meronyms = list()

            synsetList = wordnet.synsets(word)
            for synset in synsetList:
                hypernyms.append(synset.hypernyms())
                hyponyms.append(synset.hyponyms())
                holonyms.append(synset.holonyms())
                meronyms.append(synset.meronyms())
                pass

            wordnetted = {"hypernyms" : hypernyms,
             "hyponyms" : hyponyms,
             "holonyms" : holonyms,
             "meronyms" : meronyms}
            
            DOC_WORDS.append({word : {"pos" : pos, "stemmed" : stemmed, "lemma" : lemma, "wordneted" : wordnetted}})
            pass
        pass
    
    inputContainer.get("Input").update({"deptree" : parse_tree, "DOC_WORDS" : DOC_WORDS})
    
    return inputContainer
    pass

# %%
def toList(part, wordList):
    parts = list()
    
    for words in wordList:
        for w in words:
            parts.append((w, words[w][part]))
            pass
        pass
    
    return parts
    pass

# %%
def getSimilarity(part, containerDict, inputDict):
    similarity = 0
    
    conParts = toList(part, containerDict["DOC_WORDS"])
    inParts = toList(part, inputDict["DOC_WORDS"])
        
    # Calculate Cosine Similarity
    def get_cosine(vec1, vec2):
        intersection = set(vec1.keys()) & set(vec2.keys())
        numerator = sum([vec1[x] * vec2[x] for x in intersection])
        
        sum1 = sum([vec1[x]**2 for x in vec1.keys()])
        sum2 = sum([vec2[x]**2 for x in vec2.keys()])
        denominator = math.sqrt(sum1) * math.sqrt(sum2)
        
        if not denominator:
            return 0.0
            pass
        else:
            return float(numerator) / denominator
            pass
        pass
            
    conCounter = Counter(conParts)
    inCounter = Counter(inParts)
    
    similarity = get_cosine(conCounter, inCounter)
    return similarity
    pass

# %%
def testSimilarity(inputContainer):
    availableParts = ["pos", "stemmed", "lemma"]
    wordNetSimList = list()
    
    for availablePart in availableParts:
        print("TESTING FOR {}".format(availablePart))
        
        simList = list()
        for doc in container:
            similarity = getSimilarity(availablePart, container[doc], inputContainer["Input"])
            simList.append((doc, similarity))
            
            totalWordnetSimilarity = getWordnetSimilarity(container[doc], inputContainer["Input"])
            wordNetSimList.append((doc, totalWordnetSimilarity))
            pass
        
        print(sorted(simList, key = lambda x : x[1], reverse = True)[:10])
        
        # simList.clear()
        del simList
        
        print("\n\n\n")
        pass
    
    print("TESTING FOR wordnet")
    print(sorted(set(wordNetSimList), key = lambda x : x[1], reverse = True)[:10])
        
    print("\n\n\n")
    pass

# %%
def prettyContainerDoc(qa):
    pprint(qa.get("deptree"))
    
    for doc in qa["DOC_WORDS"]:
        # print(doc.keys())
        for d in doc.keys():
            # print("""
            # {:-^13} : {}
            # {:-^13} : {}
            # {:-^13} : {}
            # {:-^13} : {}
            # """.format("Word", d,
              #       "POS Tags", doc[d]["pos"],
               #      "Stem", doc[d]["stemmed"],
                #     "Lemma", doc[d]["lemma"]))
                
            print("""
            {:-^13} : {}
            {:-^13} : {}
            """.format("Word", d,
                     "Stem", doc[d]["stemmed"]))
            
            print("""
            {:-^13} : {}
            {:-^13} : {}
            {:-^13} : {}
            {:-^13} : {}
            """.format("Hypernyms", doc[d]["wordneted"]["hypernyms"],
                       "Hyponyms", doc[d]["wordneted"]["hyponyms"],
                       "Holonyms", doc[d]["wordneted"]["holonyms"],
                       "Meronyms", doc[d]["wordneted"]["meronyms"]))

            pass
        pass
    
    
    print("""{:-^13} : {}""".format("WM Distance", qa.get("WM Distance")))
    
    pass

# %%
def calcWMDistance(inSentence):
    wmDistDict = dict()
    
    for doc in range(len(documents)):
        distance = model.wmdistance(documents[doc], inSentence)
        wmDistDict.update({"DOC {}".format(doc) : distance})
        
        container["DOC {}".format(doc)].update({"WM Distance" : distance})
        pass
    
    return wmDistDict
    pass

# %%
def getWordnetSimilarity(containerDict, inputDict):
    wordnetSimilarityDict = dict()
    totalSimilarity = 0
    
    containerHeads = containerDict["heads"]
    inputHeads = inputDict["heads"]
    
    for containerHead in containerHeads:
        for inputHead in inputHeads:
            containerHeadSynsets = wordnet.synsets(containerHead)
            inputHeadSynsets = wordnet.synsets(inputHead)
            
            for containerHeadSynset in containerHeadSynsets:
                for inputHeadSynset in inputHeadSynsets:
                    sim = wordnet.similarity(containerHeadSynset, inputHeadSynset)
                    wordnetSimilarityDict.update({"{}_{}".format(containerHead, inputHead) : sim})
                    totalSimilarity += sim
                    pass
                pass
            pass
        pass
    
    return totalSimilarity
    pass

# %%
parsetree("Hello", lemmata = True)
# Out:
# [Sentence('Hello/UH/O/O/hello')]

# %%
model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
inSentence = input()
# Out:
# How many systems can I link simultaneously with my account?

# %%
qlines = list()
alines = list()
documents = list()
qaDocs = list()
container = dict()

# %%
readAndCreateCorpus()

# %%
createContainer()

# %%
bagofwords = [Counter(re.findall(r'\w+', txt)) for txt in documents]

# %%
match_qa_pair(inSentence)
# Out:
# The matching question is: How many systems can I link simultaneously with my account?
#
# The matching answer is: You can link upto 3 systems with a single account.

# %%
for qa in container:
    prettyContainerDoc(container[qa])
    pass
# Out:
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#           What   WP     -       -      -      -      what
#           ways   NNS    NP      -      -      -      way
#             do   VBP    VP      -      -      -      do
#            you   PRP    NP      -      -      -      you
#        support   VB     VP      -      -      -      support
#        payment   NN     NP      -      -      -      payment
#              ?   .      -       -      -      -      ?
#
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#            You   PRP    NP      -      -      -      you
#            can   MD     VP      -      -      -      can
#            pay   VB     VP ^    -      -      -      pay
#          using   VBG    VP ^    -      -      -      used
#              a   DT     NP      -      -      -      a
#         credit   NN     NP ^    -      -      -      credit
#             or   CC     -       -      -      -      or
#          debit   NN     NP      -      -      -      debit
#           card   NN     NP ^    -      -      -      card
#              .   .      -       -      -      -      .
#
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#            You   PRP    NP      -      -      -      you
#            can   MD     VP      -      -      -      can
#           also   RB     VP ^    -      -      -      also
#            use   VB     VP ^    -      -      -      use
#           your   PRP$   NP      -      -      -      your
#       GameLink   NN     NP ^    -      -      -      gamelink
#         points   NNS    NP ^    -      -      -      point
#             to   TO     VP      -      -      -      to
#            pay   VB     VP ^    -      -      -      pay
#            for   IN     PP      -      -      PNP    for
#          items   NNS    NP      -      -      PNP    item
#              .   .      -       -      -      -      .
#
#             ----Word----- : What
#             ----Stem----- : what
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : ways
#             ----Stem----- : way
#
#
#             --Hypernyms-- : [[Synset('structure.n.01')], [Synset('property.n.02')], [Synset('implementation.n.02')], [Synset('path.n.03')], [Synset('condition.n.01')], [Synset('course.n.04')], [Synset('artifact.n.01')], [Synset('journey.n.01')], [Synset('position.n.07')], [Synset('distance.n.01')], [Synset('choice.n.01')], [Synset('category.n.02')], [Synset('share.n.01')]]
#             --Hyponyms--- : [[], [Synset('artistic_style.n.01'), Synset('drape.n.02'), Synset('fit.n.03'), Synset('form.n.11'), Synset('life_style.n.01'), Synset('response.n.07'), Synset('setup.n.02'), Synset('touch.n.04'), Synset('wise.n.01')], [Synset('desperate_measure.n.01'), Synset('dint.n.01'), Synset('escape.n.05'), Synset('expedient.n.01'), Synset('fast_track.n.01'), Synset('instrument.n.02'), Synset('open_sesame.n.01'), Synset('road.n.02'), Synset('salvation.n.02'), Synset('stepping_stone.n.02'), Synset('tooth.n.04'), Synset('voice.n.05'), Synset('wings.n.01')], [Synset('bearing.n.02'), Synset('course.n.03'), Synset('east-west_direction.n.01'), Synset('north-south_direction.n.01'), Synset('qibla.n.01'), Synset('tendency.n.04')], [], [Synset('ambages.n.01'), Synset('primrose_path.n.01'), Synset('straight_and_narrow.n.01'), Synset('sunnah.n.01'), Synset('warpath.n.02')], [Synset('access.n.03'), Synset('lane.n.01'), Synset('passage.n.03'), Synset('path.n.02'), Synset('road.n.01'), Synset('stairway.n.01'), Synset('watercourse.n.03')], [], [Synset('breathing_room.n.01'), Synset('headroom.n.01'), Synset('houseroom.n.01'), Synset('living_space.n.01'), Synset('parking.n.01'), Synset('sea_room.n.01'), Synset('seating.n.01'), Synset('standing_room.n.01')], [], [], [], []]
#             --Holonyms--- : [[Synset('shipyard.n.01')], [], [], [], [], [], [Synset('transportation_system.n.01')], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [Synset('wayside.n.01')], [], [], [], [], [], []]
#
#
#             ----Word----- : do
#             ----Stem----- : do
#
#
#             --Hypernyms-- : [[Synset('party.n.04')], [Synset('solfa_syllable.n.01')], [Synset('doctor's_degree.n.01')]]
#             --Hyponyms--- : [[], [], []]
#             --Holonyms--- : [[], [], []]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : you
#             ----Stem----- : you
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : support
#             ----Stem----- : support
#
#
#             --Hypernyms-- : [[Synset('activity.n.01')], [Synset('aid.n.02')], [Synset('influence.n.03')], [Synset('operation.n.05')], [Synset('validation.n.01')], [Synset('resource.n.01')], [Synset('supporting_structure.n.01')], [Synset('activity.n.01')], [Synset('part.n.11')], [Synset('device.n.01')], [Synset('resource.n.01')]]
#             --Hyponyms--- : [[Synset('logistic_support.n.01'), Synset('sustenance.n.03')], [Synset('advocacy.n.01'), Synset('attachment.n.05'), Synset('blessing.n.01'), Synset('endorsement.n.05'), Synset('reassurance.n.01'), Synset('sponsorship.n.01')], [Synset('anchor.n.02'), Synset('lifeline.n.02')], [Synset('close_support.n.01')], [], [Synset('comforts.n.01'), Synset('maintenance.n.02'), Synset('meal_ticket.n.01'), Synset('subsistence.n.01')], [Synset('abutment.n.02'), Synset('architrave.n.02'), Synset('basement.n.02'), Synset('buttress.n.01'), Synset('foundation.n.03'), Synset('pedestal.n.03'), Synset('prop.n.01')], [Synset('shoring.n.02'), Synset('suspension.n.06')], [Synset('descant.n.01'), Synset('vamp.n.02')], [Synset('andiron.n.01'), Synset('arch_support.n.01'), Synset('back.n.08'), Synset('backboard.n.02'), Synset('baluster.n.01'), Synset('bar.n.13'), Synset('base.n.08'), Synset('bearing.n.06'), Synset('bearing_wall.n.01'), Synset('bedpost.n.01'), Synset('bookend.n.01'), Synset('brace.n.01'), Synset('bracket.n.04'), Synset('bridge.n.06'), Synset('foot.n.11'), Synset('foothold.n.02'), Synset('handrest.n.01'), Synset('hanger.n.02'), Synset('harness.n.01'), Synset('harp.n.02'), Synset('headstock.n.01'), Synset('leg.n.03'), Synset('perch.n.01'), Synset('pier.n.02'), Synset('pier.n.03'), Synset('pillow_block.n.01'), Synset('rack.n.05'), Synset('rest.n.06'), Synset('rib.n.01'), Synset('rocker.n.07'), Synset('seat.n.04'), Synset('shelf.n.01'), Synset('spoke.n.01'), Synset('step.n.04'), Synset('stirrup.n.01'), Synset('stock.n.03'), Synset('structural_member.n.01'), Synset('tailstock.n.01'), Synset('tee.n.02'), Synset('undercarriage.n.01'), Synset('yoke.n.05')], []]
#             --Holonyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : payment
#             ----Stem----- : payment
#
#
#             --Hypernyms-- : [[Synset('cost.n.01')], [Synset('commerce.n.01')], [Synset('return.n.10')]]
#             --Hyponyms--- : [[Synset('benefit.n.01'), Synset('blood_money.n.03'), Synset('bonus.n.02'), Synset('bribe.n.01'), Synset('cash.n.02'), Synset('conscience_money.n.01'), Synset('credit.n.05'), Synset('down_payment.n.01'), Synset('installment.n.01'), Synset('lump_sum.n.01'), Synset('overpayment.n.01'), Synset('payoff.n.01'), Synset('penalty.n.02'), Synset('pittance.n.01'), Synset('premium.n.01'), Synset('recompense.n.01'), Synset('refund.n.01'), Synset('regular_payment.n.01'), Synset('remittance.n.01'), Synset('repayment.n.02'), Synset('residual.n.02'), Synset('reward.n.02'), Synset('royalty.n.01'), Synset('satisfaction.n.04'), Synset('subscription.n.01'), Synset('support_payment.n.01'), Synset('token_payment.n.01'), Synset('underpayment.n.01')], [Synset('amortization.n.02'), Synset('fee_splitting.n.01'), Synset('overpayment.n.02'), Synset('prepayment.n.01'), Synset('ransom.n.02'), Synset('refund.n.02'), Synset('remuneration.n.02'), Synset('rendering.n.07'), Synset('spending.n.01'), Synset('tribute.n.02'), Synset('underpayment.n.02')], []]
#             --Holonyms--- : [[], [], []]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : ?
#             ----Stem----- : ?
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : You
#             ----Stem----- : you
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : can
#             ----Stem----- : can
#
#
#             --Hypernyms-- : [[Synset('container.n.01')], [Synset('containerful.n.01')], [Synset('buoy.n.01')], [Synset('body_part.n.01')], [Synset('plumbing_fixture.n.01')], [Synset('room.n.01')]]
#             --Hyponyms--- : [[Synset('beer_can.n.01'), Synset('caddy.n.01'), Synset('cannikin.n.02'), Synset('coffee_can.n.01'), Synset('milk_can.n.01'), Synset('oilcan.n.01'), Synset('soda_can.n.01')], [], [], [], [Synset('flush_toilet.n.01'), Synset('flushless_toilet.n.01'), Synset('potty_seat.n.01')], [Synset('head.n.30'), Synset('public_toilet.n.01'), Synset('washroom.n.01'), Synset('water_closet.n.01')]]
#             --Holonyms--- : [[], [], [], [Synset('torso.n.01')], [Synset('bathroom.n.01'), Synset('toilet.n.01')], []]
#             --Meronyms--- : [[], [], [], [], [Synset('toilet_bowl.n.01'), Synset('toilet_seat.n.01')], [Synset('toilet.n.02')]]
#
#
#             ----Word----- : pay
#             ----Stem----- : pay
#
#
#             --Hypernyms-- : [[Synset('regular_payment.n.01')]]
#             --Hyponyms--- : [[Synset('combat_pay.n.01'), Synset('double_time.n.02'), Synset('found.n.01'), Synset('half-pay.n.01'), Synset('living_wage.n.01'), Synset('merit_pay.n.01'), Synset('minimum_wage.n.01'), Synset('pay_envelope.n.01'), Synset('sick_pay.n.01'), Synset('strike_pay.n.01'), Synset('take-home_pay.n.01')]]
#             --Holonyms--- : [[Synset('payroll.n.01')]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : using
#             ----Stem----- : using
#
#
#             --Hypernyms-- : [[Synset('mistreatment.n.01')]]
#             --Hyponyms--- : [[Synset('blaxploitation.n.01'), Synset('colonialism.n.01'), Synset('sexploitation.n.01')]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : a
#             ----Stem----- : a
#
#
#             --Hypernyms-- : [[Synset('metric_linear_unit.n.01')], [Synset('fat-soluble_vitamin.n.01')], [Synset('nucleotide.n.01')], [Synset('purine.n.01')], [Synset('current_unit.n.01')], [Synset('letter.n.02')], [Synset('blood_group.n.01')]]
#             --Hyponyms--- : [[], [Synset('vitamin_a1.n.01'), Synset('vitamin_a2.n.01')], [], [], [], [], []]
#             --Holonyms--- : [[Synset('nanometer.n.01')], [], [], [], [Synset('abampere.n.01')], [Synset('roman_alphabet.n.01')], []]
#             --Meronyms--- : [[Synset('picometer.n.01')], [], [], [], [Synset('milliampere.n.01')], [], []]
#
#
#             ----Word----- : credit
#             ----Stem----- : credit
#
#
#             --Hypernyms-- : [[Synset('approval.n.04')], [Synset('assets.n.01')], [Synset('entry.n.03')], [Synset('accomplishment.n.01')], [Synset('payment.n.01')], [Synset('attainment.n.01')], [Synset('note.n.07')], [Synset('title.n.03')], [Synset('estimate.n.01')]]
#             --Hyponyms--- : [[Synset('memorial.n.01'), Synset('ovation.n.01'), Synset('salute.n.01')], [Synset('cheap_money.n.01'), Synset('commercial_credit.n.01'), Synset('credit_line.n.01'), Synset('export_credit.n.01'), Synset('import_credit.n.01'), Synset('letter_of_credit.n.01')], [], [], [], [Synset('semester_hour.n.01')], [Synset('cross-reference.n.01'), Synset('photo_credit.n.01')], [], []]
#             --Holonyms--- : [[], [], [], [], [], [], [], [Synset('movie.n.01')], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : or
#             ----Stem----- : or
#
#
#             --Hypernyms-- : [[], [Synset('hospital_room.n.01')]]
#             --Hyponyms--- : [[], []]
#             --Holonyms--- : [[Synset('united_states.n.01')], []]
#             --Meronyms--- : [[Synset('bend.n.05'), Synset('crater_lake_national_park.n.01'), Synset('eugene.n.02'), Synset('klamath.n.01'), Synset('klamath_falls.n.01'), Synset('medford.n.01'), Synset('pacific_northwest.n.01'), Synset('portland.n.01'), Synset('salem.n.01'), Synset('snake.n.03'), Synset('willamette.n.01')], []]
#
#
#             ----Word----- : debit
#             ----Stem----- : debit
#
#
#             --Hypernyms-- : [[Synset('entry.n.03')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : card
#             ----Stem----- : card
#
#
#             --Hypernyms-- : [[Synset('paper.n.01')], [Synset('positive_identification.n.01')], [Synset('correspondence.n.01')], [Synset('cardboard.n.01')], [Synset('humorist.n.01')], [Synset('sign.n.02')], [Synset('greeting.n.01')], [Synset('record.n.05')], [Synset('bill.n.07')], [Synset('roll.n.02')], [Synset('printed_circuit.n.01')]]
#             --Hyponyms--- : [[Synset('playing_card.n.01'), Synset('punched_card.n.01'), Synset('tarot_card.n.01'), Synset('trading_card.n.01')], [Synset('business_card.n.01'), Synset('donor_card.n.01'), Synset('keycard.n.01'), Synset('library_card.n.01'), Synset('membership_card.n.01'), Synset('ration_card.n.01')], [Synset('get-well_card.n.01'), Synset('greeting_card.n.01'), Synset('postcard.n.01'), Synset('sympathy_card.n.01')], [Synset('timecard.n.02')], [], [Synset('flash_card.n.01'), Synset('show_bill.n.01')], [], [], [Synset('a_la_carte.n.01'), Synset('prix_fixe.n.01'), Synset('table_d'hote.n.01')], [], [Synset('cpu_board.n.01'), Synset('pc_board.n.01')]]
#             --Holonyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [Synset('cleanup.n.02')], []]
#
#
#             ----Word----- : .
#             ----Stem----- : .
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : You
#             ----Stem----- : you
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : can
#             ----Stem----- : can
#
#
#             --Hypernyms-- : [[Synset('container.n.01')], [Synset('containerful.n.01')], [Synset('buoy.n.01')], [Synset('body_part.n.01')], [Synset('plumbing_fixture.n.01')], [Synset('room.n.01')]]
#             --Hyponyms--- : [[Synset('beer_can.n.01'), Synset('caddy.n.01'), Synset('cannikin.n.02'), Synset('coffee_can.n.01'), Synset('milk_can.n.01'), Synset('oilcan.n.01'), Synset('soda_can.n.01')], [], [], [], [Synset('flush_toilet.n.01'), Synset('flushless_toilet.n.01'), Synset('potty_seat.n.01')], [Synset('head.n.30'), Synset('public_toilet.n.01'), Synset('washroom.n.01'), Synset('water_closet.n.01')]]
#             --Holonyms--- : [[], [], [], [Synset('torso.n.01')], [Synset('bathroom.n.01'), Synset('toilet.n.01')], []]
#             --Meronyms--- : [[], [], [], [], [Synset('toilet_bowl.n.01'), Synset('toilet_seat.n.01')], [Synset('toilet.n.02')]]
#
#
#             ----Word----- : also
#             ----Stem----- : also
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : use
#             ----Stem----- : use
#
#
#             --Hypernyms-- : [[Synset('activity.n.01')], [Synset('utility.n.02')], [Synset('utility.n.02')], [Synset('demand.n.02')], [Synset('custom.n.01')], [Synset('influence.n.02')], [Synset('legal_right.n.01')]]
#             --Hyponyms--- : [[Synset('application.n.01'), Synset('exploitation.n.01'), Synset('misuse.n.01'), Synset('play.n.06'), Synset('practice.n.04'), Synset('recycling.n.01')], [Synset('raison_d'etre.n.02')], [], [Synset('conspicuous_consumption.n.01')], [Synset('cleanliness.n.01'), Synset('ritual.n.03'), Synset('second_nature.n.01')], [Synset('mind_game.n.02')], [Synset('fair_use.n.01'), Synset('fruition.n.02')]]
#             --Holonyms--- : [[], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], []]
#
#
#             ----Word----- : your
#             ----Stem----- : ymy
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : GameLink
#             ----Stem----- : gamelink
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : points
#             ----Stem----- : point
#
#
#             --Hypernyms-- : [[Synset('component.n.01')], [Synset('location.n.01')], [Synset('meaning.n.01')], [Synset('fact.n.01')], [Synset('state.n.02')], [Synset('measure.n.02')], [Synset('aim.n.02')], [Synset('convex_shape.n.01')], [Synset('disk.n.01')], [Synset('unit_of_measurement.n.01')], [Synset('promontory.n.01')], [Synset('part.n.01')], [Synset('relevance.n.01')], [Synset('characteristic.n.02')], [Synset('end.n.01')], [Synset('direction.n.02')], [Synset('linear_unit.n.01')], [Synset('loan.n.01')], [Synset('punctuation.n.02')], [Synset('mark.n.10')], [Synset('mathematical_notation.n.01')], [Synset('taper.n.02')], [Synset('characteristic.n.02')], [Synset('gun_muzzle.n.01')], [Synset('wall_socket.n.01')], [Synset('contact.n.07')]]
#             --Hyponyms--- : [[Synset('attractor.n.02'), Synset('intercept.n.01'), Synset('intersection.n.01')], [Synset('abutment.n.01'), Synset('antinode.n.01'), Synset('beginning.n.04'), Synset('blind_spot.n.02'), Synset('celestial_point.n.01'), Synset('center.n.04'), Synset('chokepoint.n.02'), Synset('corner.n.02'), Synset('corner.n.05'), Synset('crossing.n.03'), Synset('focus.n.04'), Synset('focus.n.06'), Synset('focus.n.07'), Synset('geographic_point.n.01'), Synset('ground_zero.n.03'), Synset('hilum.n.02'), Synset('hot_spot.n.02'), Synset('mcburney's_point.n.01'), Synset('midair.n.01'), Synset('military_position.n.01'), Synset('navel.n.01'), Synset('node.n.04'), Synset('position.n.01'), Synset('position.n.08'), Synset('pressure_point.n.01'), Synset('punctum.n.01'), Synset('topographic_point.n.01'), Synset('trichion.n.01'), Synset('vanishing_point.n.01')], [Synset('bottom_line.n.02'), Synset('crux.n.02'), Synset('rallying_point.n.01'), Synset('talking_point.n.01')], [Synset('minutia.n.01'), Synset('nook_and_cranny.n.01'), Synset('respect.n.01'), Synset('sticking_point.n.01'), Synset('technicality.n.01')], [Synset('acme.n.01'), Synset('climax.n.04'), Synset('extent.n.01'), Synset('ladder.n.02'), Synset('plane.n.03'), Synset('quickening.n.02'), Synset('resultant.n.01'), Synset('standard_of_living.n.01'), Synset('state_of_the_art.n.01'), Synset('ultimacy.n.01')], [Synset('arrival_time.n.01'), Synset('beginning.n.02'), Synset('date.n.04'), Synset('deadline.n.01'), Synset('departure_time.n.01'), Synset('distance.n.06'), Synset('end.n.02'), Synset('middle.n.04'), Synset('midterm.n.01'), Synset('midterm.n.02'), Synset('moment.n.01'), Synset('phase.n.03'), Synset('run-time.n.01'), Synset('show_time.n.01'), Synset('term.n.06'), Synset('then.n.01')], [], [Synset('cusp.n.03'), Synset('head.n.10'), Synset('widow's_peak.n.01')], [], [Synset('advantage.n.02'), Synset('match_point.n.01'), Synset('point_after.n.01'), Synset('set_point.n.01')], [], [Synset('agenda_item.n.01'), Synset('incidental.n.02'), Synset('inventory_item.n.01'), Synset('line_item.n.01'), Synset('news_item.n.01'), Synset('place.n.15')], [], [], [Synset('arrowhead.n.01'), Synset('barb.n.02'), Synset('barb.n.03'), Synset('cusp.n.01'), Synset('diamond_point.n.01'), Synset('nib.n.01'), Synset('pike.n.03'), Synset('pinpoint.n.03'), Synset('spearhead.n.03'), Synset('spike.n.07')], [Synset('cardinal_compass_point.n.01'), Synset('east_by_north.n.01'), Synset('east_by_south.n.01'), Synset('east_northeast.n.01'), Synset('east_southeast.n.01'), Synset('north_by_east.n.01'), Synset('north_by_west.n.01'), Synset('north_northeast.n.01'), Synset('north_northwest.n.01'), Synset('northeast.n.01'), Synset('northeast_by_east.n.01'), Synset('northeast_by_north.n.01'), Synset('northwest.n.03'), Synset('northwest_by_north.n.01'), Synset('northwest_by_west.n.01'), Synset('south_by_east.n.01'), Synset('south_by_west.n.01'), Synset('south_southeast.n.01'), Synset('south_southwest.n.01'), Synset('southeast.n.01'), Synset('southeast_by_east.n.01'), Synset('southeast_by_south.n.01'), Synset('southwest.n.01'), Synset('southwest_by_south.n.01'), Synset('southwest_by_west.n.01'), Synset('west_by_north.n.01'), Synset('west_by_south.n.01'), Synset('west_northwest.n.01'), Synset('west_southwest.n.01')], [], [], [Synset('suspension_point.n.01')], [], [], [], [Synset('selling_point.n.01')], [], [], []]
#             --Holonyms--- : [[], [], [], [], [], [], [], [Synset('alpenstock.n.01'), Synset('arrowhead.n.01'), Synset('cone.n.02'), Synset('knife.n.02'), Synset('pencil.n.01'), Synset('sword.n.01')], [], [Synset('score.n.03')], [], [Synset('list.n.01')], [], [], [Synset('awl.n.01'), Synset('icepick.n.01'), Synset('knife.n.01'), Synset('needle.n.03'), Synset('pencil.n.01'), Synset('pin.n.09')], [], [Synset('em.n.02')], [], [], [Synset('arrow.n.01')], [], [], [], [], [], [Synset('distributor.n.04')]]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : to
#             ----Stem----- : to
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : pay
#             ----Stem----- : pay
#
#
#             --Hypernyms-- : [[Synset('regular_payment.n.01')]]
#             --Hyponyms--- : [[Synset('combat_pay.n.01'), Synset('double_time.n.02'), Synset('found.n.01'), Synset('half-pay.n.01'), Synset('living_wage.n.01'), Synset('merit_pay.n.01'), Synset('minimum_wage.n.01'), Synset('pay_envelope.n.01'), Synset('sick_pay.n.01'), Synset('strike_pay.n.01'), Synset('take-home_pay.n.01')]]
#             --Holonyms--- : [[Synset('payroll.n.01')]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : for
#             ----Stem----- : for
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : items
#             ----Stem----- : item
#
#
#             --Hypernyms-- : [[Synset('part.n.01')], [Synset('part.n.01')], [Synset('whole.n.02')], [Synset('fact.n.01')], [Synset('symbol.n.01')]]
#             --Hyponyms--- : [[Synset('agenda_item.n.01'), Synset('incidental.n.02'), Synset('inventory_item.n.01'), Synset('line_item.n.01'), Synset('news_item.n.01'), Synset('place.n.15')], [Synset('highlight.n.01')], [Synset('custom-made.n.01'), Synset('disposable.n.01'), Synset('piece.n.02')], [Synset('minutia.n.01'), Synset('nook_and_cranny.n.01'), Synset('respect.n.01'), Synset('sticking_point.n.01'), Synset('technicality.n.01')], [Synset('postage.n.02'), Synset('trading_stamp.n.01')]]
#             --Holonyms--- : [[Synset('list.n.01')], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], []]
#
#
#             ----Word----- : .
#             ----Stem----- : .
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
# -WM Distance- : None
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#            Can   MD     VP      -      -      -      can
#              I   PRP    NP      -      -      -      i
#      pre-order   VBP    VP      -      -      -      pre-order
#          games   NNS    NP      -      -      -      game
#             on   IN     PP      -      -      PNP    on
#            the   DT     NP      -      -      PNP    the
#           site   NN     NP ^    -      -      PNP    site
#              ?   .      -       -      -      -      ?
#
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#            Yes   UH     -       -      -      -      yes
#              ,   ,      -       -      -      -      ,
#            you   PRP    NP      -      -      -      you
#            can   MD     VP      -      -      -      can
#     definitely   RB     NP      -      -      -      definitely
#      pre-order   JJ     NP ^    -      -      -      pre-order
#          games   NNS    NP ^    -      -      -      game
#             on   IN     PP      -      -      PNP    on
#            our   PRP$   NP      -      -      PNP    our
#           site   NN     NP ^    -      -      PNP    site
#              .   .      -       -      -      -      .
#
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#           Some   DT     NP      -      -      -      some
#          games   NNS    NP ^    -      -      -      game
#           also   RB     VP      -      -      -      also
#          offer   VBP    VP ^    -      -      -      offer
#      pre-order   NN     NP      -      -      -      pre-order
#        bonuses   NNS    NP ^    -      -      -      bonuse
#            and   CC     NP ^    -      -      -      and
#      discounts   NNS    NP ^    -      -      -      discount
#              .   .      -       -      -      -      .
#
#             ----Word----- : Can
#             ----Stem----- : can
#
#
#             --Hypernyms-- : [[Synset('container.n.01')], [Synset('containerful.n.01')], [Synset('buoy.n.01')], [Synset('body_part.n.01')], [Synset('plumbing_fixture.n.01')], [Synset('room.n.01')]]
#             --Hyponyms--- : [[Synset('beer_can.n.01'), Synset('caddy.n.01'), Synset('cannikin.n.02'), Synset('coffee_can.n.01'), Synset('milk_can.n.01'), Synset('oilcan.n.01'), Synset('soda_can.n.01')], [], [], [], [Synset('flush_toilet.n.01'), Synset('flushless_toilet.n.01'), Synset('potty_seat.n.01')], [Synset('head.n.30'), Synset('public_toilet.n.01'), Synset('washroom.n.01'), Synset('water_closet.n.01')]]
#             --Holonyms--- : [[], [], [], [Synset('torso.n.01')], [Synset('bathroom.n.01'), Synset('toilet.n.01')], []]
#             --Meronyms--- : [[], [], [], [], [Synset('toilet_bowl.n.01'), Synset('toilet_seat.n.01')], [Synset('toilet.n.02')]]
#
#
#             ----Word----- : I
#             ----Stem----- : i
#
#
#             --Hypernyms-- : [[Synset('chemical_element.n.01'), Synset('halogen.n.01')], [Synset('digit.n.01')], [Synset('letter.n.02')]]
#             --Hyponyms--- : [[Synset('iodine-125.n.01'), Synset('iodine-131.n.01')], [Synset('monad.n.02'), Synset('singleton.n.01')], []]
#             --Holonyms--- : [[], [], [Synset('roman_alphabet.n.01')]]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : pre-order
#             ----Stem----- : pre-order
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : games
#             ----Stem----- : game
#
#
#             --Hypernyms-- : [[Synset('activity.n.01')], [Synset('contest.n.01')], [Synset('diversion.n.01')], [Synset('animal.n.01')], [Synset('part.n.09')], [Synset('score.n.03')], [Synset('meat.n.01')], [Synset('scheme.n.01')], [Synset('game_equipment.n.01')], [Synset('occupation.n.01')], [Synset('play.n.14')]]
#             --Hyponyms--- : [[Synset('athletic_game.n.01'), Synset('bowling.n.01'), Synset('card_game.n.01'), Synset('child's_game.n.01'), Synset('curling.n.01'), Synset('game_of_chance.n.01'), Synset('pall-mall.n.01'), Synset('parlor_game.n.01'), Synset('table_game.n.01'), Synset('zero-sum_game.n.01')], [Synset('away_game.n.01'), Synset('cup_tie.n.01'), Synset('exhibition_game.n.01'), Synset('home_game.n.01'), Synset('nightcap.n.03'), Synset('playoff_game.n.01'), Synset('twin_bill.n.01')], [Synset('catch.n.08'), Synset('computer_game.n.01'), Synset('ducks_and_drakes.n.01'), Synset('guessing_game.n.01'), Synset('mind_game.n.01'), Synset('paper_chase.n.01'), Synset('party_game.n.01'), Synset('pinball.n.01'), Synset('prisoner's_base.n.01'), Synset('ring-around-the-rosy.n.01'), Synset('treasure_hunt.n.01')], [Synset('big_game.n.01'), Synset('game_bird.n.01')], [], [], [Synset('buffalo.n.03'), Synset('rabbit.n.03'), Synset('venison.n.01')], [Synset('conspiracy.n.02'), Synset('counterplot.n.01'), Synset('intrigue.n.01')], [Synset('puzzle.n.02')], [], []]
#             --Holonyms--- : [[], [], [], [], [Synset('set.n.08')], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : on
#             ----Stem----- : on
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : the
#             ----Stem----- : the
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : site
#             ----Stem----- : site
#
#
#             --Hypernyms-- : [[Synset('tract.n.01')], [Synset('position.n.01')], [Synset('computer.n.01')]]
#             --Hyponyms--- : [[Synset('apron.n.02'), Synset('bomb_site.n.01'), Synset('camp.n.08'), Synset('campsite.n.01'), Synset('cemetery.n.01'), Synset('dig.n.01'), Synset('dump.n.02'), Synset('fairway.n.01'), Synset('green.n.06'), Synset('launching_site.n.01'), Synset('monument.n.02'), Synset('premises.n.01'), Synset('rough.n.01'), Synset('tee.n.01'), Synset('toxic_site.n.01')], [Synset('active_site.n.01'), Synset('antigenic_determinant.n.01'), Synset('close_quarters.n.01'), Synset('locus.n.02'), Synset('locus_of_infection.n.01'), Synset('restriction_site.n.01')], [Synset('chat_room.n.01'), Synset('portal_site.n.01')]]
#             --Holonyms--- : [[], [], []]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : ?
#             ----Stem----- : ?
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : Yes
#             ----Stem----- : ye
#
#
#             --Hypernyms-- : [[Synset('affirmative.n.01')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : ,
#             ----Stem----- : ,
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : you
#             ----Stem----- : you
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : can
#             ----Stem----- : can
#
#
#             --Hypernyms-- : [[Synset('container.n.01')], [Synset('containerful.n.01')], [Synset('buoy.n.01')], [Synset('body_part.n.01')], [Synset('plumbing_fixture.n.01')], [Synset('room.n.01')]]
#             --Hyponyms--- : [[Synset('beer_can.n.01'), Synset('caddy.n.01'), Synset('cannikin.n.02'), Synset('coffee_can.n.01'), Synset('milk_can.n.01'), Synset('oilcan.n.01'), Synset('soda_can.n.01')], [], [], [], [Synset('flush_toilet.n.01'), Synset('flushless_toilet.n.01'), Synset('potty_seat.n.01')], [Synset('head.n.30'), Synset('public_toilet.n.01'), Synset('washroom.n.01'), Synset('water_closet.n.01')]]
#             --Holonyms--- : [[], [], [], [Synset('torso.n.01')], [Synset('bathroom.n.01'), Synset('toilet.n.01')], []]
#             --Meronyms--- : [[], [], [], [], [Synset('toilet_bowl.n.01'), Synset('toilet_seat.n.01')], [Synset('toilet.n.02')]]
#
#
#             ----Word----- : definitely
#             ----Stem----- : definitely
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : pre-order
#             ----Stem----- : pre-order
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : games
#             ----Stem----- : game
#
#
#             --Hypernyms-- : [[Synset('activity.n.01')], [Synset('contest.n.01')], [Synset('diversion.n.01')], [Synset('animal.n.01')], [Synset('part.n.09')], [Synset('score.n.03')], [Synset('meat.n.01')], [Synset('scheme.n.01')], [Synset('game_equipment.n.01')], [Synset('occupation.n.01')], [Synset('play.n.14')]]
#             --Hyponyms--- : [[Synset('athletic_game.n.01'), Synset('bowling.n.01'), Synset('card_game.n.01'), Synset('child's_game.n.01'), Synset('curling.n.01'), Synset('game_of_chance.n.01'), Synset('pall-mall.n.01'), Synset('parlor_game.n.01'), Synset('table_game.n.01'), Synset('zero-sum_game.n.01')], [Synset('away_game.n.01'), Synset('cup_tie.n.01'), Synset('exhibition_game.n.01'), Synset('home_game.n.01'), Synset('nightcap.n.03'), Synset('playoff_game.n.01'), Synset('twin_bill.n.01')], [Synset('catch.n.08'), Synset('computer_game.n.01'), Synset('ducks_and_drakes.n.01'), Synset('guessing_game.n.01'), Synset('mind_game.n.01'), Synset('paper_chase.n.01'), Synset('party_game.n.01'), Synset('pinball.n.01'), Synset('prisoner's_base.n.01'), Synset('ring-around-the-rosy.n.01'), Synset('treasure_hunt.n.01')], [Synset('big_game.n.01'), Synset('game_bird.n.01')], [], [], [Synset('buffalo.n.03'), Synset('rabbit.n.03'), Synset('venison.n.01')], [Synset('conspiracy.n.02'), Synset('counterplot.n.01'), Synset('intrigue.n.01')], [Synset('puzzle.n.02')], [], []]
#             --Holonyms--- : [[], [], [], [], [Synset('set.n.08')], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : on
#             ----Stem----- : on
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : our
#             ----Stem----- : my
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : site
#             ----Stem----- : site
#
#
#             --Hypernyms-- : [[Synset('tract.n.01')], [Synset('position.n.01')], [Synset('computer.n.01')]]
#             --Hyponyms--- : [[Synset('apron.n.02'), Synset('bomb_site.n.01'), Synset('camp.n.08'), Synset('campsite.n.01'), Synset('cemetery.n.01'), Synset('dig.n.01'), Synset('dump.n.02'), Synset('fairway.n.01'), Synset('green.n.06'), Synset('launching_site.n.01'), Synset('monument.n.02'), Synset('premises.n.01'), Synset('rough.n.01'), Synset('tee.n.01'), Synset('toxic_site.n.01')], [Synset('active_site.n.01'), Synset('antigenic_determinant.n.01'), Synset('close_quarters.n.01'), Synset('locus.n.02'), Synset('locus_of_infection.n.01'), Synset('restriction_site.n.01')], [Synset('chat_room.n.01'), Synset('portal_site.n.01')]]
#             --Holonyms--- : [[], [], []]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : .
#             ----Stem----- : .
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : Some
#             ----Stem----- : some
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : games
#             ----Stem----- : game
#
#
#             --Hypernyms-- : [[Synset('activity.n.01')], [Synset('contest.n.01')], [Synset('diversion.n.01')], [Synset('animal.n.01')], [Synset('part.n.09')], [Synset('score.n.03')], [Synset('meat.n.01')], [Synset('scheme.n.01')], [Synset('game_equipment.n.01')], [Synset('occupation.n.01')], [Synset('play.n.14')]]
#             --Hyponyms--- : [[Synset('athletic_game.n.01'), Synset('bowling.n.01'), Synset('card_game.n.01'), Synset('child's_game.n.01'), Synset('curling.n.01'), Synset('game_of_chance.n.01'), Synset('pall-mall.n.01'), Synset('parlor_game.n.01'), Synset('table_game.n.01'), Synset('zero-sum_game.n.01')], [Synset('away_game.n.01'), Synset('cup_tie.n.01'), Synset('exhibition_game.n.01'), Synset('home_game.n.01'), Synset('nightcap.n.03'), Synset('playoff_game.n.01'), Synset('twin_bill.n.01')], [Synset('catch.n.08'), Synset('computer_game.n.01'), Synset('ducks_and_drakes.n.01'), Synset('guessing_game.n.01'), Synset('mind_game.n.01'), Synset('paper_chase.n.01'), Synset('party_game.n.01'), Synset('pinball.n.01'), Synset('prisoner's_base.n.01'), Synset('ring-around-the-rosy.n.01'), Synset('treasure_hunt.n.01')], [Synset('big_game.n.01'), Synset('game_bird.n.01')], [], [], [Synset('buffalo.n.03'), Synset('rabbit.n.03'), Synset('venison.n.01')], [Synset('conspiracy.n.02'), Synset('counterplot.n.01'), Synset('intrigue.n.01')], [Synset('puzzle.n.02')], [], []]
#             --Holonyms--- : [[], [], [], [], [Synset('set.n.08')], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : also
#             ----Stem----- : also
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : offer
#             ----Stem----- : offer
#
#
#             --Hypernyms-- : [[Synset('speech_act.n.01')], [Synset('message.n.02')], [Synset('attempt.n.01')]]
#             --Hyponyms--- : [[], [Synset('bid.n.03'), Synset('contract_offer.n.01'), Synset('counteroffer.n.01'), Synset('marriage_proposal.n.01'), Synset('peace_offering.n.01'), Synset('proposition.n.03'), Synset('prospectus.n.01'), Synset('reward.n.04'), Synset('rights_offering.n.01'), Synset('special.n.01'), Synset('tender_offer.n.01'), Synset('twofer.n.01')], []]
#             --Holonyms--- : [[], [], []]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : pre-order
#             ----Stem----- : pre-order
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : bonuses
#             ----Stem----- : bonuse
#
#
#             --Hypernyms-- : [[Synset('positive_stimulus.n.01')], [Synset('payment.n.01')]]
#             --Hyponyms--- : [[], [Synset('dividend.n.03'), Synset('premium.n.04'), Synset('sales_incentive.n.01')]]
#             --Holonyms--- : [[], [Synset('incentive_program.n.01')]]
#             --Meronyms--- : [[], []]
#
#
#             ----Word----- : and
#             ----Stem----- : and
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : discounts
#             ----Stem----- : discount
#
#
#             --Hypernyms-- : [[Synset('decrease.n.04')], [Synset('interest_rate.n.01')], [Synset('refund.n.01')], [Synset('allowance.n.03')]]
#             --Hyponyms--- : [[], [Synset('bank_rate.n.01')], [Synset('rent-rebate.n.01')], [Synset('trade_discount.n.01')]]
#             --Holonyms--- : [[], [], [], []]
#             --Meronyms--- : [[], [], [], []]
#
#
#             ----Word----- : .
#             ----Stem----- : .
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
# -WM Distance- : None
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#            Can   MD     VP      -      -      -      can
#              I   PRP    NP      -      -      -      i
#            get   VBP    VP      -      -      -      get
#              a   DT     NP      -      -      -      a
#         refund   NN     NP ^    -      -      -      refund
#            for   IN     PP      -      -      PNP    for
#              a   DT     NP      -      -      PNP    a
#           game   NN     NP ^    -      -      PNP    game
#              I   PRP    NP ^    -      -      PNP    i
#       didnâ€™t   VBP    VP      -      -      -      didnâ€™t
#           like   IN     PP      -      -      -      like
#             or   CC     -       -      -      -      or
#       wasnâ€™t   VBD    VP      -      -      -      wasnâ€™t
#           able   JJ     ADJP    -      -      -      able
#             to   TO     VP      -      -      -      to
#            run   VB     VP ^    -      -      -      run
#             on   IN     PP      -      -      PNP    on
#             my   PRP$   NP      -      -      PNP    my
#         system   NN     NP ^    -      -      PNP    system
#              ?   .      -       -      -      -      ?
#
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#            Yes   UH     -       -      -      -      yes
#              ,   ,      -       -      -      -      ,
#            you   PRP    NP      -      -      -      you
#            can   MD     VP      -      -      -      can
#            get   VB     VP ^    -      -      -      get
#              a   DT     NP      -      -      -      a
#         refund   NN     NP ^    -      -      -      refund
#            for   IN     PP      -      -      PNP    for
#              a   DT     NP      -      -      PNP    a
#           game   NN     NP ^    -      -      PNP    game
#             if   IN     PP      -      -      PNP    if
#            you   PRP    NP      -      -      PNP    you
#          apply   VBP    VP      -      -      -      apply
#            for   IN     PP      -      -      PNP    for
#             it   PRP    NP      -      -      PNP    it
#         within   IN     PP      -      -      PNP    within
#             15   CD     NP      -      -      PNP    15
#           days   NNS    NP ^    -      -      PNP    day
#             of   IN     PP      -      -      PNP    of
#       purchase   NN     NP      -      -      PNP    purchase
#              .   .      -       -      -      -      .
#
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#         Please   NN     NP      -      -      -      please
#        refrain   NN     NP ^    -      -      -      refrain
#           from   IN     PP      -      -      PNP    from
#       misusing   VBG    VP      -      -      PNP    misuse
#           this   DT     NP      -      -      PNP    this
#        feature   NN     NP ^    -      -      PNP    feature
#              .   .      -       -      -      -      .
#
#             ----Word----- : Can
#             ----Stem----- : can
#
#
#             --Hypernyms-- : [[Synset('container.n.01')], [Synset('containerful.n.01')], [Synset('buoy.n.01')], [Synset('body_part.n.01')], [Synset('plumbing_fixture.n.01')], [Synset('room.n.01')]]
#             --Hyponyms--- : [[Synset('beer_can.n.01'), Synset('caddy.n.01'), Synset('cannikin.n.02'), Synset('coffee_can.n.01'), Synset('milk_can.n.01'), Synset('oilcan.n.01'), Synset('soda_can.n.01')], [], [], [], [Synset('flush_toilet.n.01'), Synset('flushless_toilet.n.01'), Synset('potty_seat.n.01')], [Synset('head.n.30'), Synset('public_toilet.n.01'), Synset('washroom.n.01'), Synset('water_closet.n.01')]]
#             --Holonyms--- : [[], [], [], [Synset('torso.n.01')], [Synset('bathroom.n.01'), Synset('toilet.n.01')], []]
#             --Meronyms--- : [[], [], [], [], [Synset('toilet_bowl.n.01'), Synset('toilet_seat.n.01')], [Synset('toilet.n.02')]]
#
#
#             ----Word----- : I
#             ----Stem----- : i
#
#
#             --Hypernyms-- : [[Synset('chemical_element.n.01'), Synset('halogen.n.01')], [Synset('digit.n.01')], [Synset('letter.n.02')]]
#             --Hyponyms--- : [[Synset('iodine-125.n.01'), Synset('iodine-131.n.01')], [Synset('monad.n.02'), Synset('singleton.n.01')], []]
#             --Holonyms--- : [[], [], [Synset('roman_alphabet.n.01')]]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : get
#             ----Stem----- : get
#
#
#             --Hypernyms-- : [[Synset('return.n.11')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : a
#             ----Stem----- : a
#
#
#             --Hypernyms-- : [[Synset('metric_linear_unit.n.01')], [Synset('fat-soluble_vitamin.n.01')], [Synset('nucleotide.n.01')], [Synset('purine.n.01')], [Synset('current_unit.n.01')], [Synset('letter.n.02')], [Synset('blood_group.n.01')]]
#             --Hyponyms--- : [[], [Synset('vitamin_a1.n.01'), Synset('vitamin_a2.n.01')], [], [], [], [], []]
#             --Holonyms--- : [[Synset('nanometer.n.01')], [], [], [], [Synset('abampere.n.01')], [Synset('roman_alphabet.n.01')], []]
#             --Meronyms--- : [[Synset('picometer.n.01')], [], [], [], [Synset('milliampere.n.01')], [], []]
#
#
#             ----Word----- : refund
#             ----Stem----- : refund
#
#
#             --Hypernyms-- : [[Synset('payment.n.01')], [Synset('payment.n.02')]]
#             --Hyponyms--- : [[Synset('rebate.n.01')], []]
#             --Holonyms--- : [[], []]
#             --Meronyms--- : [[], []]
#
#
#             ----Word----- : for
#             ----Stem----- : for
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : a
#             ----Stem----- : a
#
#
#             --Hypernyms-- : [[Synset('metric_linear_unit.n.01')], [Synset('fat-soluble_vitamin.n.01')], [Synset('nucleotide.n.01')], [Synset('purine.n.01')], [Synset('current_unit.n.01')], [Synset('letter.n.02')], [Synset('blood_group.n.01')]]
#             --Hyponyms--- : [[], [Synset('vitamin_a1.n.01'), Synset('vitamin_a2.n.01')], [], [], [], [], []]
# ...
#             --Holonyms--- : [[], [], [], [], [Synset('agreement.n.01')], [], [Synset('proposition.n.01')], [Synset('gestation.n.01')], []]
#             --Meronyms--- : [[], [], [], [Synset('midterm.n.02')], [], [], [], [], []]
#
#
#             ----Word----- : of
#             ----Stem----- : of
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : service
#             ----Stem----- : service
#
#
#             --Hypernyms-- : [[Synset('work.n.01')], [Synset('aid.n.02')], [Synset('religious_ceremony.n.01')], [Synset('company.n.01')], [Synset('employment.n.02')], [Synset('force.n.04')], [], [Synset('helpfulness.n.01')], [Synset('tableware.n.01')], [Synset('coupling.n.03')], [Synset('activity.n.01')], [Synset('tennis_stroke.n.01')], [Synset('delivery.n.01')], [Synset('care.n.06')], [Synset('accommodation.n.05')]]
#             --Hyponyms--- : [[Synset('consulting_service.n.01'), Synset('facility.n.05'), Synset('national_service.n.01'), Synset('utility.n.03')], [Synset('childcare.n.01'), Synset('community_service.n.01'), Synset('community_service.n.02'), Synset('help_desk.n.01'), Synset('seating.n.02')], [Synset('chapel_service.n.01'), Synset('church_service.n.01'), Synset('committal_service.n.01'), Synset('devotional.n.01'), Synset('none.n.02'), Synset('prayer_meeting.n.01'), Synset('vesper.n.02'), Synset('watch_night.n.01')], [Synset('utility.n.01')], [], [Synset('air_force.n.01'), Synset('army.n.01'), Synset('coastguard.n.01'), Synset('marines.n.01'), Synset('navy.n.01')], [], [], [Synset('dinner_service.n.01'), Synset('place_setting.n.01')], [], [Synset('knight's_service.n.01'), Synset('military_service.n.02'), Synset('socage.n.01')], [Synset('ace.n.06'), Synset('fault.n.07'), Synset('let.n.02')], [], [Synset('interim_overhaul.n.01')], [Synset('curb_service.n.01'), Synset('self-service.n.01'), Synset('valet_parking.n.01')]]
#             --Holonyms--- : [[], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [Synset('invocation.n.01')], [], [], [Synset('military_unit.n.01')], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : and
#             ----Stem----- : and
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : may
#             ----Stem----- : may
#
#
#             --Hypernyms-- : [[Synset('gregorian_calendar_month.n.01')], [Synset('hawthorn.n.01')]]
#             --Hyponyms--- : [[], []]
#             --Holonyms--- : [[Synset('gregorian_calendar.n.01')], [Synset('crataegus.n.01')]]
#             --Meronyms--- : [[Synset('armed_forces_day.n.01'), Synset('commonwealth_day.n.01'), Synset('may_day.n.01'), Synset('memorial_day.n.01'), Synset('mid-may.n.01'), Synset('mother's_day.n.01')], []]
#
#
#             ----Word----- : be
#             ----Stem----- : be
#
#
#             --Hypernyms-- : [[Synset('metallic_element.n.01')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : considered
#             ----Stem----- : considered
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : piracy
#             ----Stem----- : piracy
#
#
#             --Hypernyms-- : [[Synset('highjacking.n.01')], [Synset('copyright_infringement.n.01')]]
#             --Hyponyms--- : [[], []]
#             --Holonyms--- : [[], []]
#             --Meronyms--- : [[], []]
#
#
#             ----Word----- : .
#             ----Stem----- : .
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
# -WM Distance- : None
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#             Do   VB     VP      -      -      -      do
#             my   PRP$   NP      -      -      -      my
#           game   NN     NP ^    -      -      -      game
#          saves   VBZ    VP      -      -      -      save
#            get   VB     VP ^    -      -      -      get
#         synced   VBN    VP ^    -      -      -      sync
#           with   IN     PP      -      -      PNP    with
#           your   PRP$   NP      -      -      PNP    your
#         server   NN     NP ^    -      -      PNP    server
#              ?   .      -       -      -      -      ?
#
#           WORD   TAG    CHUNK   ROLE   ID     PNP    LEMMA
#
#            Yes   UH     -       -      -      -      yes
#              ,   ,      -       -      -      -      ,
#             an   DT     NP      -      -      -      an
#         online   JJ     NP ^    -      -      -      online
#     connection   NN     NP ^    -      -      -      connection
#        ensures   VBZ    VP      -      -      -      ensure
#            all   DT     NP      -      -      -      all
#           your   PRP$   NP ^    -      -      -      your
#           game   NN     NP ^    -      -      -      game
#          saves   VBZ    VP      -      -      -      save
#            are   VBP    VP ^    -      -      -      be
#         synced   VBN    VP ^    -      -      -      sync
#         online   JJ     ADJP    -      -      -      online
#              .   .      -       -      -      -      .
#
#             ----Word----- : Do
#             ----Stem----- : do
#
#
#             --Hypernyms-- : [[Synset('party.n.04')], [Synset('solfa_syllable.n.01')], [Synset('doctor's_degree.n.01')]]
#             --Hyponyms--- : [[], [], []]
#             --Holonyms--- : [[], [], []]
#             --Meronyms--- : [[], [], []]
#
#
#             ----Word----- : my
#             ----Stem----- : my
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : game
#             ----Stem----- : game
#
#
#             --Hypernyms-- : [[Synset('activity.n.01')], [Synset('contest.n.01')], [Synset('diversion.n.01')], [Synset('animal.n.01')], [Synset('part.n.09')], [Synset('score.n.03')], [Synset('meat.n.01')], [Synset('scheme.n.01')], [Synset('game_equipment.n.01')], [Synset('occupation.n.01')], [Synset('play.n.14')]]
#             --Hyponyms--- : [[Synset('athletic_game.n.01'), Synset('bowling.n.01'), Synset('card_game.n.01'), Synset('child's_game.n.01'), Synset('curling.n.01'), Synset('game_of_chance.n.01'), Synset('pall-mall.n.01'), Synset('parlor_game.n.01'), Synset('table_game.n.01'), Synset('zero-sum_game.n.01')], [Synset('away_game.n.01'), Synset('cup_tie.n.01'), Synset('exhibition_game.n.01'), Synset('home_game.n.01'), Synset('nightcap.n.03'), Synset('playoff_game.n.01'), Synset('twin_bill.n.01')], [Synset('catch.n.08'), Synset('computer_game.n.01'), Synset('ducks_and_drakes.n.01'), Synset('guessing_game.n.01'), Synset('mind_game.n.01'), Synset('paper_chase.n.01'), Synset('party_game.n.01'), Synset('pinball.n.01'), Synset('prisoner's_base.n.01'), Synset('ring-around-the-rosy.n.01'), Synset('treasure_hunt.n.01')], [Synset('big_game.n.01'), Synset('game_bird.n.01')], [], [], [Synset('buffalo.n.03'), Synset('rabbit.n.03'), Synset('venison.n.01')], [Synset('conspiracy.n.02'), Synset('counterplot.n.01'), Synset('intrigue.n.01')], [Synset('puzzle.n.02')], [], []]
#             --Holonyms--- : [[], [], [], [], [Synset('set.n.08')], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : saves
#             ----Stem----- : save
#
#
#             --Hypernyms-- : [[Synset('prevention.n.01')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : get
#             ----Stem----- : get
#
#
#             --Hypernyms-- : [[Synset('return.n.11')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : synced
#             ----Stem----- : synced
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : with
#             ----Stem----- : with
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : your
#             ----Stem----- : ymy
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : server
#             ----Stem----- : server
#
#
#             --Hypernyms-- : [[Synset('dining-room_attendant.n.01')], [Synset('player.n.01')], [Synset('computer.n.01')], [Synset('utensil.n.01')]]
#             --Hyponyms--- : [[Synset('carhop.n.01'), Synset('counterperson.n.01'), Synset('sommelier.n.01'), Synset('waitress.n.01')], [], [], []]
#             --Holonyms--- : [[], [], [Synset('computer_network.n.01')], []]
#             --Meronyms--- : [[], [], [], []]
#
#
#             ----Word----- : ?
#             ----Stem----- : ?
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : Yes
#             ----Stem----- : ye
#
#
#             --Hypernyms-- : [[Synset('affirmative.n.01')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : ,
#             ----Stem----- : ,
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : an
#             ----Stem----- : an
#
#
#             --Hypernyms-- : [[Synset('associate_degree.n.01')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : online
#             ----Stem----- : online
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : connection
#             ----Stem----- : connection
#
#
#             --Hypernyms-- : [[Synset('relation.n.01')], [Synset('union.n.04')], [Synset('instrumentality.n.03')], [Synset('acquaintance.n.03')], [Synset('memory.n.02')], [Synset('shape.n.02')], [Synset('supplier.n.01')], [Synset('transportation.n.02')], [Synset('change_of_integrity.n.01')]]
#             --Hyponyms--- : [[Synset('alliance.n.02'), Synset('bridge.n.03'), Synset('communication.n.03'), Synset('concatenation.n.02'), Synset('involvement.n.02'), Synset('linkage.n.01'), Synset('relatedness.n.01'), Synset('relevance.n.01'), Synset('series.n.05')], [Synset('coherence.n.01'), Synset('concatenation.n.01'), Synset('contact.n.03'), Synset('interconnection.n.01')], [Synset('attachment.n.04'), Synset('backbone.n.05'), Synset('ground.n.09'), Synset('hitch.n.04'), Synset('hookup.n.01'), Synset('jumper.n.05'), Synset('junction.n.04'), Synset('slip_ring.n.01'), Synset('telephone_line.n.02'), Synset('temporary_hookup.n.01'), Synset('yoke.n.06')], [], [Synset('colligation.n.02')], [Synset('articulation.n.02'), Synset('node.n.01')], [], [], [Synset('approximation.n.04'), Synset('articulation.n.05'), Synset('concatenation.n.04'), Synset('convergence.n.04'), Synset('encounter.n.03'), Synset('fastening.n.02'), Synset('hit.n.07'), Synset('interconnection.n.02'), Synset('intersection.n.06'), Synset('junction.n.05')]]
#             --Holonyms--- : [[], [], [], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : ensures
#             ----Stem----- : ensure
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : all
#             ----Stem----- : all
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : your
#             ----Stem----- : ymy
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : game
#             ----Stem----- : game
#
#
#             --Hypernyms-- : [[Synset('activity.n.01')], [Synset('contest.n.01')], [Synset('diversion.n.01')], [Synset('animal.n.01')], [Synset('part.n.09')], [Synset('score.n.03')], [Synset('meat.n.01')], [Synset('scheme.n.01')], [Synset('game_equipment.n.01')], [Synset('occupation.n.01')], [Synset('play.n.14')]]
#             --Hyponyms--- : [[Synset('athletic_game.n.01'), Synset('bowling.n.01'), Synset('card_game.n.01'), Synset('child's_game.n.01'), Synset('curling.n.01'), Synset('game_of_chance.n.01'), Synset('pall-mall.n.01'), Synset('parlor_game.n.01'), Synset('table_game.n.01'), Synset('zero-sum_game.n.01')], [Synset('away_game.n.01'), Synset('cup_tie.n.01'), Synset('exhibition_game.n.01'), Synset('home_game.n.01'), Synset('nightcap.n.03'), Synset('playoff_game.n.01'), Synset('twin_bill.n.01')], [Synset('catch.n.08'), Synset('computer_game.n.01'), Synset('ducks_and_drakes.n.01'), Synset('guessing_game.n.01'), Synset('mind_game.n.01'), Synset('paper_chase.n.01'), Synset('party_game.n.01'), Synset('pinball.n.01'), Synset('prisoner's_base.n.01'), Synset('ring-around-the-rosy.n.01'), Synset('treasure_hunt.n.01')], [Synset('big_game.n.01'), Synset('game_bird.n.01')], [], [], [Synset('buffalo.n.03'), Synset('rabbit.n.03'), Synset('venison.n.01')], [Synset('conspiracy.n.02'), Synset('counterplot.n.01'), Synset('intrigue.n.01')], [Synset('puzzle.n.02')], [], []]
#             --Holonyms--- : [[], [], [], [], [Synset('set.n.08')], [], [], [], [], [], []]
#             --Meronyms--- : [[], [], [], [], [], [], [], [], [], [], []]
#
#
#             ----Word----- : saves
#             ----Stem----- : save
#
#
#             --Hypernyms-- : [[Synset('prevention.n.01')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : are
#             ----Stem----- : are
#
#
#             --Hypernyms-- : [[Synset('area_unit.n.01')]]
#             --Hyponyms--- : [[]]
#             --Holonyms--- : [[Synset('hectare.n.01')]]
#             --Meronyms--- : [[]]
#
#
#             ----Word----- : synced
#             ----Stem----- : synced
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : online
#             ----Stem----- : online
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
#
#             ----Word----- : .
#             ----Stem----- : .
#
#
#             --Hypernyms-- : []
#             --Hyponyms--- : []
#             --Holonyms--- : []
#             --Meronyms--- : []
#
# -WM Distance- : None

# %%
wmDistance = calcWMDistance(inSentence)
sorted(wmDistance.items(), key = operator.itemgetter(1))[:10]
# Out:
# [('DOC 19', 0.27055288860296917),
#  ('DOC 17', 0.7870174806979101),
#  ('DOC 20', 0.8688072545395806),
#  ('DOC 14', 0.9044911523019552),
#  ('DOC 24', 0.9424520374228315),
#  ('DOC 18', 0.947977346033127),
#  ('DOC 43', 0.9533117972694977),
#  ('DOC 0', 0.9570868387800772),
#  ('DOC 50', 0.9657944299630516),
#  ('DOC 49', 0.9888544324659416)]

# %%
inputContainer = createInputContainer(inSentence)

# %%
testSimilarity(inputContainer)
# Out:
# TESTING FOR pos
# [('DOC 19', 0.8257228238447705), ('DOC 18', 0.42640143271122094), ('DOC 17', 0.351839597706834), ('DOC 14', 0.3302891295379082), ('DOC 34', 0.3289758474798845), ('DOC 49', 0.30151134457776363), ('DOC 20', 0.2934695928267111), ('DOC 33', 0.27524094128159016), ('DOC 12', 0.2279211529192759), ('DOC 47', 0.22613350843332272)]
#
#
#
#
# TESTING FOR stemmed
# [('DOC 19', 0.8528028654224417), ('DOC 18', 0.42640143271122094), ('DOC 17', 0.3876574430285532), ('DOC 14', 0.3302891295379082), ('DOC 34', 0.3289758474798845), ('DOC 49', 0.30151134457776363), ('DOC 20', 0.28603877677367767), ('DOC 33', 0.27524094128159016), ('DOC 47', 0.22613350843332272), ('DOC 13', 0.22395700438234173)]
#
#
#
#
# TESTING FOR lemma
# [('DOC 19', 0.8528028654224417), ('DOC 18', 0.42640143271122094), ('DOC 17', 0.3876574430285532), ('DOC 14', 0.3302891295379082), ('DOC 34', 0.3289758474798845), ('DOC 49', 0.30151134457776363), ('DOC 20', 0.28603877677367767), ('DOC 33', 0.27524094128159016), ('DOC 47', 0.22613350843332272), ('DOC 13', 0.22395700438234173)]
#
#
#
#
# TESTING FOR wordnet
# [('DOC 34', 285.79323161777756), ('DOC 20', 194.32960725019024), ('DOC 35', 142.97570910062097), ('DOC 23', 137.62865695504405), ('DOC 42', 136.6183526797143), ('DOC 12', 129.81976047512973), ('DOC 4', 127.18579707404007), ('DOC 30', 123.71615662141285), ('DOC 14', 121.6987488521247), ('DOC 0', 111.61887741446048)]

# %%
questions = ["How do I pay for games?",
"How many genres of games do you have?",
"Do I need the client to play games?",
"How can I use your streaming service?",
"Can achievements be purchased on the store?",
"Are game saves automatically synced with the server?",
"Can I buy concept art for different games?",
"Can I back up my games?",
"Do you have an in-game chat service?",
"Do you have level and map editors for games?"]

# %%
for question in questions:    
    print(question + "\n")
    
    #match_qa_pair(question)
    
    wmDistance = calcWMDistance(question)
    #print(sorted(wmDistance.items(), key = operator.itemgetter(1))[:10])
    
    inputContainer = createInputContainer(question)
    
    #testSimilarity(inputContainer)
    
    """
    posWeight = 0.1
    stemmedWeight = 0.3
    lemmaWeight = 0.3
    wmWeight = 0.0
    """
    
    
    posWeight = 0.1
    stemmedWeight = 0.3
    lemmaWeight = 0.3
    wmWeight = 0.01
    
    pslWeights = PSL(inputContainer, posWeight, stemmedWeight, lemmaWeight)
    
    # print(pslWeights)
    
    totalWeights = dict()
    for psl, wm in zip(sorted(pslWeights.items()), sorted(wmDistance.items())):
        # print(psl[1], wm[1] * 0.1)
        totalWeights.update({psl[0] : (psl[1] + (wm[1] * wmWeight))})
        pass
    
    print(sorted(totalWeights.items(), key = operator.itemgetter(1), reverse = True)[:10])
    # print(totalWeights)
    
    print("\n\n\n\n\n")
    pass
# Out:
# How do I pay for games?
#
# [('DOC 38', 0.13102062512018384), ('DOC 26', 0.12729014352924567), ('DOC 25', 0.12508798877921026), ('DOC 7', 0.1084954584912395), ('DOC 36', 0.1055567603354672), ('DOC 43', 0.10512767744923524), ('DOC 0', 0.10503793464248438), ('DOC 32', 0.10460229142786791), ('DOC 21', 0.1042822657802534), ('DOC 46', 0.10423922457025568)]
#
#
#
#
#
#
# How many genres of games do you have?
#
# [('DOC 6', 0.17603893984336785), ('DOC 36', 0.1271282630679571), ('DOC 5', 0.12569159583350703), ('DOC 44', 0.12370976680039912), ('DOC 7', 0.11886419553175484), ('DOC 4', 0.11383554456353635), ('DOC 26', 0.11076117669088217), ('DOC 39', 0.10676612249830392), ('DOC 18', 0.10636010355136906), ('DOC 11', 0.09731614252145468)]
#
#
#
#
#
#
# Do I need the client to play games?
#
# [('DOC 28', 0.21600764735153632), ('DOC 21', 0.17813896749195365), ('DOC 29', 0.16926287741138335), ('DOC 44', 0.1624825113551426), ('DOC 24', 0.15091267748562975), ('DOC 3', 0.1462807867981468), ('DOC 13', 0.13989742775684721), ('DOC 30', 0.13629661131879675), ('DOC 23', 0.13197086935494468), ('DOC 38', 0.13002819303668361)]
#
#
#
#
#
#
# How can I use your streaming service?
#
# [('DOC 12', 0.10441123041247413), ('DOC 19', 0.10326579932597435), ('DOC 0', 0.09791199243778602), ('DOC 37', 0.09469678461764723), ('DOC 49', 0.09022814062418529), ('DOC 35', 0.08912290282409334), ('DOC 18', 0.08627646351627535), ('DOC 17', 0.08450132539860275), ('DOC 34', 0.07699518947599494), ('DOC 20', 0.0749469395737624)]
#
#
#
#
#
#
# Can achievements be purchased on the store?
#
# [('DOC 51', 0.1428035694558781), ('DOC 29', 0.14272337525072376), ('DOC 12', 0.1220615262368023), ('DOC 21', 0.1055391485395322), ('DOC 3', 0.10210950704891912), ('DOC 16', 0.0969502740931404), ('DOC 30', 0.09404477880714866), ('DOC 53', 0.09285147626911977), ('DOC 48', 0.09160339818679294), ('DOC 47', 0.0912044832354801)]
#
#
#
#
#
#
# Are game saves automatically synced with the server?
#
# [('DOC 54', 0.16030766810428443), ('DOC 41', 0.105571407315768), ('DOC 3', 0.09672453420168789), ('DOC 16', 0.09020718635100237), ('DOC 15', 0.08686505579670765), ('DOC 31', 0.08410335836060627), ('DOC 14', 0.08159801453705827), ('DOC 27', 0.07796436027666051), ('DOC 10', 0.06994614573293206), ('DOC 9', 0.06942116832030942)]
#
#
#
#
#
#
# Can I buy concept art for different games?
#
# [('DOC 45', 0.11920734303780221), ('DOC 23', 0.11492688811205076), ('DOC 51', 0.11351873489743415), ('DOC 25', 0.10713794024248975), ('DOC 30', 0.10409078739159036), ('DOC 42', 0.10342622406577731), ('DOC 21', 0.1013617623644266), ('DOC 14', 0.10089765133507585), ('DOC 26', 0.09668378204938881), ('DOC 29', 0.09663028566598808)]
#
#
#
#
#
#
# Can I back up my games?
#
# [('DOC 14', 0.16032776975847068), ('DOC 8', 0.1494028683151965), ('DOC 38', 0.13370666642895626), ('DOC 46', 0.12972778489447145), ('DOC 53', 0.12784735378344775), ('DOC 47', 0.12778278479489416), ('DOC 34', 0.1271640128697124), ('DOC 21', 0.12353707189606442), ('DOC 45', 0.12242664183507261), ('DOC 13', 0.1208659309180717)]
#
#
#
#
#
#
# Do you have an in-game chat service?
#
# [('DOC 36', 0.214397497541872), ('DOC 11', 0.15682998674787763), ('DOC 52', 0.11928935392443114), ('DOC 37', 0.11873805705721045), ('DOC 9', 0.11279661784484843), ('DOC 41', 0.11271937062677807), ('DOC 44', 0.11052416334054195), ('DOC 6', 0.10774770415118662), ('DOC 4', 0.10072531494012234), ('DOC 10', 0.09741150551587921)]
#
#
#
#
#
#
# Do you have level and map editors for games?
#
# [('DOC 36', 0.15573440749794074), ('DOC 9', 0.138095126891102), ('DOC 44', 0.13350367839708543), ('DOC 6', 0.13137002737972353), ('DOC 25', 0.13074686602160396), ('DOC 4', 0.12201609202268002), ('DOC 39', 0.12115929304225102), ('DOC 26', 0.12037299572228348), ('DOC 5', 0.1193837434228525), ('DOC 7', 0.10968212326353399)]

# %%
def PSL(inputContainer, posWeight, stemmedWeight, lemmaWeight):
    weightedSum = dict()
    
    availableParts = ["pos", "stemmed", "lemma"]
    wordNetSimList = list()
    
    for availablePart in availableParts:        
        simList = list()
        for doc in container:
            similarity = getSimilarity(availablePart, container[doc], inputContainer["Input"])
            
            if availablePart == "pos":
                similarity *= posWeight
                pass
            elif availablePart == "stemmed":
                similarity *= stemmedWeight
                pass
            elif availablePart == "lemma":
                similarity *= lemmaWeight
                pass
            
            simList.append((doc, similarity))
            
            # totalWordnetSimilarity = getWordnetSimilarity(container[doc], inputContainer["Input"])
            totalWordnetSimilarity = 0.0
            wordNetSimList.append((doc, totalWordnetSimilarity))
            
            weightedSum.update({doc : similarity + totalWordnetSimilarity})
            pass
                
        del simList
        pass
    
    # print(weightedSum)
    
    return weightedSum
    pass
